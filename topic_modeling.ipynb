# %%
import numpy as np
import pandas as pd

from sklearn.decomposition import TruncatedSVD, NMF
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from gensim import corpora, models, similarities, matutils

import preprocessing
import vectorize

# %%
documents = preprocessing.get_clean_tweets(subset=10000)

# %%
len(documents)
# Out:
# 9997

# %%
cv, cv_names = vectorize.get_count_vectorized(documents)

# %%
tfidf, tfidf_names = vectorize.get_tfidf_vectorized(documents)

# %%
tfidf.shape
# Out:
# (9997, 10788)

# %%
lsa = TruncatedSVD(2)
lsa_topic = lsa.fit_transform(cv)
lsa.explained_variance_ratio_
# Out:
# array([0.0694311 , 0.03757325])

# %%
topic_word = pd.DataFrame(lsa.components_, index=['component_1','component_2'], columns = cv_names)

# %%
topic_word
# Out:
#                    abaixo     abandoned      abandons       abd     abdsc  \
# component_1  4.246475e-09  7.784227e-07  8.973645e-08  0.000001  0.000036
# component_2  3.021631e-08  3.732165e-06  7.309567e-07  0.000008  0.000318
#
#                      abeg      abet   abiding     abilities   ability  \
# component_1  7.563343e-08  0.000025  0.000004  3.966989e-07  0.000027
# component_2  6.971800e-07  0.000044  0.000052  2.006524e-06  0.000052
#
#                ...     zellerbach      zero  zerotrust      zeus  \
# component_1    ...       0.000023  0.000031   0.000003  0.000004
# component_2    ...       0.000001  0.000129   0.000039  0.000068
#
#                 zhengzhou         zines      zion  zodiacal   zuckermouth  \
# component_1  8.481597e-07  6.432944e-07  0.000014  0.000002  7.685274e-08
# component_2  2.918478e-06  3.766078e-06  0.000248  0.000059  4.791190e-07
#
#                  zulu
# component_1  0.000002
# component_2  0.000005
#
# [2 rows x 10788 columns]

# %%
nmf = NMF(2)
nmf_topic = nmf.fit_transform(cv)

# %%
topic_word = pd.DataFrame(nmf.components_, index=['component_1','component_2'],columns=cv_names)

# %%
topic_word
# Out:
#                    abaixo  abandoned      abandons       abd     abdsc  \
# component_1  1.878844e-08   0.000005  3.836510e-07  0.000008  0.000122
# component_2  2.536121e-07   0.000031  6.193973e-06  0.000069  0.002733
#
#                      abeg      abet   abiding  abilities   ability    ...     \
# component_1  2.871732e-07  0.000221  0.000000   0.000003  0.000233    ...
# component_2  5.910041e-06  0.000378  0.000447   0.000017  0.000446    ...
#
#              zellerbach      zero  zerotrust      zeus  zhengzhou     zines  \
# component_1    0.000221  0.000233   0.000000  0.000000   0.000006  0.000004
# component_2    0.000014  0.001102   0.000333  0.000581   0.000025  0.000031
#
#                  zion  zodiacal   zuckermouth      zulu
# component_1  0.000000  0.000000  4.357295e-07  0.000013
# component_2  0.002104  0.000505  4.096941e-06  0.000037
#
# [2 rows x 10788 columns]

# %%
def display_topics(model, feature_names, no_top_words, topic_names=None):
    for i, topic in enumerate(model.components_):
        if not topic_names or not topic_names[i]:
            print("\nTopic ", i)
        else:
            print("\nTopic: '", topic_names[i], "'")
        print(", ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
display_topics(lsa, cv_names, 5)
# Out:
# Topic  0
# people, venezuela, need, aid, life
#
# Topic  1
# pay, think, ve, tax, fund

# %%
display_topics(nmf, cv_names, 10)
# Out:
# Topic  0
# people, venezuela, need, aid, life, children, day, maduro, nicol, humanitarian
#
# Topic  1
# pay, think, ve, tax, fund, billboards, mercers, avoidance, offshore, papers

# %%
pd.DataFrame(nmf_topic, columns = ['component_1','component_2'])
# Out:
#       component_1  component_2
# 0        0.000145     0.001145
# 1        0.024702     0.020163
# 2        0.000242     0.000866
# 3        0.000032     0.001132
# 4        0.000427     0.001281
# 5        0.000071     0.000316
# 6        0.021728     0.000412
# 7        0.000385     0.002470
# 8        0.000036     0.012331
# 9        0.000017     0.000326
# 10       0.000070     0.001619
# 11       0.000385     0.002470
# 12       0.000824     0.018469
# 13       0.000089     0.000574
# 14       0.000089     0.000574
# 15       0.000257     0.002018
# 16       0.000049     0.000423
# 17       0.000157     0.000871
# 18       0.000000     0.000068
# 19       0.000083     0.000499
# 20       0.000014     0.000254
# 21       0.000137     0.000997
# 22       0.019157     0.083424
# 23       0.000389     0.002339
# 24       0.000138     0.000912
# 25       0.000389     0.002339
# 26       0.000389     0.002339
# 27       0.000427     0.001281
# 28       0.000389     0.002339
# 29       0.000271     0.014623
# ...           ...          ...
# 9967     0.000016     0.000022
# 9968     0.000070     0.000148
# 9969     0.000000     0.345889
# 9970     0.000158     0.000927
# 9971     0.000130     0.000531
# 9972     0.000166     0.000835
# 9973     0.021309     0.000135
# 9974     0.000000     0.029387
# 9975     0.000161     0.002751
# 9976     0.000013     0.000073
# 9977     0.000000     0.000000
# 9978     0.065609     0.078336
# 9979     0.021589     0.000000
# 9980     0.024024     0.037483
# 9981     0.000000     0.000000
# 9982     0.000000     0.010933
# 9983     0.000095     0.010160
# 9984     0.001526     0.093771
# 9985     0.000292     0.002959
# 9986     0.000007     0.000028
# 9987     0.000588     0.004795
# 9988     0.000168     0.010842
# 9989     0.013651     0.442277
# 9990     0.000007     0.000009
# 9991     0.023925     0.005988
# 9992     0.000000     0.000000
# 9993     0.000438     0.013685
# 9994     0.000000     0.007614
# 9995     0.000201     0.011314
# 9996     0.000072     0.000123
#
# [9997 rows x 2 columns]
